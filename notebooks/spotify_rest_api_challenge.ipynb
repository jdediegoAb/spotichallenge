# %% [markdown]
# ![spotify_logo](../img/spotify_logo.png)
#
# # Spotify REST API Challenge
#
# __What to listen?__
#
# Create your own playlist based on the related artists and their most popular tracks using the [Spotify REST API](https://developer.spotify.com/)

# %%
# imports
import pandas as pd
import requests

# %% [markdown]
# ### Get access!!!
#
# Get your `client_id` and `client_secret` to generate your __token__ access

# %%
# generate token with a POST request

client_id = 'cce13f066b7e4dea8375d78d68b5feec'
client_secret = '7a5de9bfa7e84a86a7e0cc5bed8bc87b'
auth_url = 'https://accounts.spotify.com/api/token'

# %%
auth_response = requests.post(auth_url, {'grant_type': 'client_credentials',
                                         'client_id': client_id,
                                         'client_secret': client_secret}).json()

# %%
access_token = auth_response['access_token']
auth_response
# Out:
# {'access_token': 'BQBVwyE5V88HrQ8wp8duLVgLbsTzbHxGSHMryf40SnGj_kb8h-vBTnnX1ddGInF0kqS8juRB_dsgHOlXiIep5WHi0rdxnRTnksrN3Q71CZ6DPW9t0bc',
#  'token_type': 'Bearer',
#  'expires_in': 3600}

# %% [markdown]
# ### Set your main variables!!!
#
# Set the `base_url` (i.e.: End-point), parameters and `headers` for your __GET__ operations

# %%
# setting the main variables

base_url = 'https://api.spotify.com/v1'
resource = '/artists'
parameters='/2d0hyoQ5ynDBnkvAbJKORj/related-artists'
parameters2='/2d0hyoQ5ynDBnkvAbJKORj/top-tracks?market=ES'
header = {'Authorization': 'Bearer {token}'.format(token=access_token)}

# %% [markdown]
# ### Create your new playlist!!!
#
# Use [`/related-artists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-related-artists) and [`/top-tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-top-tracks) in order to get the data that you need
#
# __Here you have the different artists to start with:__
#
# _Option 1:_ 711MCceyCBcFnzjGY4Q7Un
#
# _Option 2:_ 5gs3QMiBgkUgNofeA16Awv
#
# _Option 3:_ 1ZcvF2meiXi5UPDJWxrKR5
#
# _Option 4:_ 0HSGpDMeXaEmH5aUIHjnBF
#
# _Option 5:_ 5TYxZTjIPqKM8K8NuP9woO
#
# _Option 6:_ 36QJpDe2go2KgaRleHCDTp
#
# _Option 7:_ 3qm84nBOXUEQ2vnTfUTTFC
#
# _Option 8:_ 4NJhFmfw43RLBLjQvxDuRS
#
# _Option 9:_ 0L8ExT028jH3ddEcZwqJJ5
#
# _Option 10:_ 1vCWHaC5f2uS3yhpwWbIA6
#
# _Option 11:_ 1dfeR4HaWDbWqFHLkxsg1d
#
# _Option 12:_ 6ogn9necmbUdCppmNnGOdi

# %%
# your code
base_url = 'https://api.spotify.com/v1'
resource = '/artists'
parameters='/2d0hyoQ5ynDBnkvAbJKORj/related-artists'
parameters2='/2d0hyoQ5ynDBnkvAbJKORj/top-tracks?market=ES'
header = {'Authorization': 'Bearer {token}'.format(token=access_token)}
url=base_url+resource
df=requests.get(url+parameters,headers=header).json()
art=pd.DataFrame.from_dict(df['artists'])
art1=art[["id","name"]]


df_list=pd.DataFrame()
for i in art1.id:
    a=requests.get(url+'/'+ i +'/top-tracks?market=ES',headers=header).json()
    track=pd.DataFrame.from_dict(a['tracks'])
    df_list=pd.concat([track,df_list])
df_list.reset_index(drop=True).head(20)
# Out:
#                                                 album  \
# 0   {'album_type': 'album', 'artists': [{'external...
# 1   {'album_type': 'album', 'artists': [{'external...
# 2   {'album_type': 'album', 'artists': [{'external...
# 3   {'album_type': 'album', 'artists': [{'external...
# 4   {'album_type': 'album', 'artists': [{'external...
# 5   {'album_type': 'album', 'artists': [{'external...
# 6   {'album_type': 'album', 'artists': [{'external...
# 7   {'album_type': 'single', 'artists': [{'externa...
# 8   {'album_type': 'album', 'artists': [{'external...
# 9   {'album_type': 'compilation', 'artists': [{'ex...
# 10  {'album_type': 'album', 'artists': [{'external...
# 11  {'album_type': 'album', 'artists': [{'external...
# 12  {'album_type': 'album', 'artists': [{'external...
# 13  {'album_type': 'album', 'artists': [{'external...
# 14  {'album_type': 'album', 'artists': [{'external...
# 15  {'album_type': 'album', 'artists': [{'external...
# 16  {'album_type': 'album', 'artists': [{'external...
# 17  {'album_type': 'album', 'artists': [{'external...
# 18  {'album_type': 'album', 'artists': [{'external...
# 19  {'album_type': 'album', 'artists': [{'external...
#
#                                               artists  disc_number  \
# 0   [{'external_urls': {'spotify': 'https://open.s...            1
# 1   [{'external_urls': {'spotify': 'https://open.s...            1
# 2   [{'external_urls': {'spotify': 'https://open.s...            1
# 3   [{'external_urls': {'spotify': 'https://open.s...            1
# 4   [{'external_urls': {'spotify': 'https://open.s...            1
# 5   [{'external_urls': {'spotify': 'https://open.s...            1
# 6   [{'external_urls': {'spotify': 'https://open.s...            1
# 7   [{'external_urls': {'spotify': 'https://open.s...            1
# 8   [{'external_urls': {'spotify': 'https://open.s...            1
# 9   [{'external_urls': {'spotify': 'https://open.s...            1
# 10  [{'external_urls': {'spotify': 'https://open.s...            1
# 11  [{'external_urls': {'spotify': 'https://open.s...            1
# 12  [{'external_urls': {'spotify': 'https://open.s...            1
# 13  [{'external_urls': {'spotify': 'https://open.s...            1
# 14  [{'external_urls': {'spotify': 'https://open.s...            1
# 15  [{'external_urls': {'spotify': 'https://open.s...            1
# 16  [{'external_urls': {'spotify': 'https://open.s...            1
# 17  [{'external_urls': {'spotify': 'https://open.s...            1
# 18  [{'external_urls': {'spotify': 'https://open.s...            1
# 19  [{'external_urls': {'spotify': 'https://open.s...            1
#
#     duration_ms  explicit              external_ids  \
# 0        216426      True  {'isrc': 'USSM10500054'}
# 1        162293     False  {'isrc': 'USSM10010700'}
# 2        172586     False  {'isrc': 'USSM10905844'}
# 3        159253      True  {'isrc': 'USSM10414146'}
# 4        215306     False  {'isrc': 'USSM10500068'}
# 5        291933      True  {'isrc': 'USSM10011159'}
# 6        231933     False  {'isrc': 'USSM10500069'}
# 7        216026     False  {'isrc': 'USSM10803645'}
# 8        243933     False  {'isrc': 'USSM10210065'}
# 9        276306      True  {'isrc': 'USSM10704840'}
# 10       302906     False  {'isrc': 'USSM11207511'}
# 11       300240     False  {'isrc': 'USSM11207515'}
# 12       456026     False  {'isrc': 'USSM11207509'}
# 13       289693     False  {'isrc': 'USSM10024272'}
# 14       337973     False  {'isrc': 'USSM11207522'}
# 15       344906     False  {'isrc': 'USSM11207512'}
# 16       267413     False  {'isrc': 'USSM11207514'}
# 17       375666     False  {'isrc': 'USSM10024270'}
# 18       289893     False  {'isrc': 'USSM11207516'}
# 19       311306     False  {'isrc': 'USSM10024269'}
#
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/track/0I...
# 1   {'spotify': 'https://open.spotify.com/track/7v...
# 2   {'spotify': 'https://open.spotify.com/track/7s...
# 3   {'spotify': 'https://open.spotify.com/track/0G...
# 4   {'spotify': 'https://open.spotify.com/track/0h...
# 5   {'spotify': 'https://open.spotify.com/track/3Y...
# 6   {'spotify': 'https://open.spotify.com/track/0U...
# 7   {'spotify': 'https://open.spotify.com/track/0i...
# 8   {'spotify': 'https://open.spotify.com/track/15...
# 9   {'spotify': 'https://open.spotify.com/track/1Z...
# 10  {'spotify': 'https://open.spotify.com/track/5E...
# 11  {'spotify': 'https://open.spotify.com/track/5D...
# 12  {'spotify': 'https://open.spotify.com/track/5x...
# 13  {'spotify': 'https://open.spotify.com/track/2H...
# 14  {'spotify': 'https://open.spotify.com/track/34...
# 15  {'spotify': 'https://open.spotify.com/track/6N...
# 16  {'spotify': 'https://open.spotify.com/track/1V...
# 17  {'spotify': 'https://open.spotify.com/track/4k...
# 18  {'spotify': 'https://open.spotify.com/track/65...
# 19  {'spotify': 'https://open.spotify.com/track/5w...
#
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/tracks/0INUE1K7cEiE...  0INUE1K7cEiE8VH63Rv5RJ
# 1   https://api.spotify.com/v1/tracks/7vrLphPq4yja...  7vrLphPq4yjaX7jiDdd2Nc
# 2   https://api.spotify.com/v1/tracks/7ss73yV5efYH...  7ss73yV5efYHgm9bAQ98JM
# 3   https://api.spotify.com/v1/tracks/0GBiT1wHV68b...  0GBiT1wHV68bU0Cv8ZU2HZ
# 4   https://api.spotify.com/v1/tracks/0h5D9uxuZRAf...  0h5D9uxuZRAfq6qMMX34vN
# 5   https://api.spotify.com/v1/tracks/3Y4rNagSf2Iu...  3Y4rNagSf2IukhcOTWYJuV
# 6   https://api.spotify.com/v1/tracks/0UvuqCD6ktYw...  0UvuqCD6ktYwIW97Pn4p2o
# 7   https://api.spotify.com/v1/tracks/0iFhShSdYvMw...  0iFhShSdYvMwscXAiUp4CT
# 8   https://api.spotify.com/v1/tracks/15TzkwxGNvM3...  15TzkwxGNvM3RGib0YkH4T
# 9   https://api.spotify.com/v1/tracks/1ZaxUokPjgc4...  1ZaxUokPjgc4Po18K7t7LW
# 10  https://api.spotify.com/v1/tracks/5EUsI3LIV042...  5EUsI3LIV042IV5ydksV9y
# 11  https://api.spotify.com/v1/tracks/5DRUgJmwLvCH...  5DRUgJmwLvCHQjiFzb4LSQ
# 12  https://api.spotify.com/v1/tracks/5xhQOnyRJfRy...  5xhQOnyRJfRywbEwpkgoTy
# 13  https://api.spotify.com/v1/tracks/2Hj2yaVFXjzh...  2Hj2yaVFXjzhQ2umr1FZCt
# 14  https://api.spotify.com/v1/tracks/34jo30lPEqp6...  34jo30lPEqp6QvJe04NAFu
# 15  https://api.spotify.com/v1/tracks/6NQZtrzKlUkY...  6NQZtrzKlUkY81Bw00avaI
# 16  https://api.spotify.com/v1/tracks/1VRgs7pDXFcW...  1VRgs7pDXFcWARLa17HE9n
# 17  https://api.spotify.com/v1/tracks/4kSIqv25W9sP...  4kSIqv25W9sPsfG45rt9kh
# 18  https://api.spotify.com/v1/tracks/653gE0Wo2LG2...  653gE0Wo2LG2Hc60P2gP5s
# 19  https://api.spotify.com/v1/tracks/5wYqKB5kuA1C...  5wYqKB5kuA1CTUi7NC60IQ
#
#     is_local  is_playable                                               name  \
# 0      False         True                                             Happy?
# 1      False         True                                                Dig
# 2      False         True                                     Scream With Me
# 3      False         True                                         Determined
# 4      False         True  Forget to Remember - From Saw II - Original So...
# 5      False         True                                       Death Blooms
# 6      False         True                                    Fall Into Sleep
# 7      False         True                                     Do What You Do
# 8      False         True                                        Not Falling
# 9      False         True                                       King Of Pain
# 10     False         True                                    River of Deceit
# 11     False         True                              I Don't Know Anything
# 12     False         True                                            Wake Up
# 13     False         True                                      Long Gone Day
# 14     False         True                                          Slip Away
# 15     False         True                                          I'm Above
# 16     False         True                                      Lifeless Dead
# 17     False         True                                     Artificial Red
# 18     False         True                                      Long Gone Day
# 19     False         True                                         X-Ray Mind
#
#     popularity                                        preview_url  \
# 0           69  https://p.scdn.co/mp3-preview/f48e996cf8b07c55...
# 1           64  https://p.scdn.co/mp3-preview/f5998f375e67fd9c...
# 2           60  https://p.scdn.co/mp3-preview/38cedc1a99a9d167...
# 3           57  https://p.scdn.co/mp3-preview/72e1f21d1844529f...
# 4           56  https://p.scdn.co/mp3-preview/31b6d3e052027145...
# 5           54  https://p.scdn.co/mp3-preview/1ef943f4886f56c9...
# 6           54  https://p.scdn.co/mp3-preview/240ac1f670e7933b...
# 7           36  https://p.scdn.co/mp3-preview/3541d1f7acaebba6...
# 8           52  https://p.scdn.co/mp3-preview/5a554cd9a5cb45f1...
# 9           50  https://p.scdn.co/mp3-preview/fed23af951b06837...
# 10          58  https://p.scdn.co/mp3-preview/65654604ed9484d9...
# 11          54  https://p.scdn.co/mp3-preview/4a41ed696edee2a1...
# 12          54  https://p.scdn.co/mp3-preview/c07bf260505c93e9...
# 13          49  https://p.scdn.co/mp3-preview/d8fd5070dffa4d75...
# 14          49  https://p.scdn.co/mp3-preview/fcb3e54d98d48c82...
# 15          47  https://p.scdn.co/mp3-preview/786816f1337292cf...
# 16          42  https://p.scdn.co/mp3-preview/a00de59d2b35a78d...
# 17          41  https://p.scdn.co/mp3-preview/214bb28678407e99...
# 18          41  https://p.scdn.co/mp3-preview/8113efb71957d144...
# 19          41  https://p.scdn.co/mp3-preview/6faa8d44d5925862...
#
#     track_number   type                                   uri
# 0              3  track  spotify:track:0INUE1K7cEiE8VH63Rv5RJ
# 1              2  track  spotify:track:7vrLphPq4yjaX7jiDdd2Nc
# 2              3  track  spotify:track:7ss73yV5efYHgm9bAQ98JM
# 3              1  track  spotify:track:0GBiT1wHV68bU0Cv8ZU2HZ
# 4              8  track  spotify:track:0h5D9uxuZRAfq6qMMX34vN
# 5              5  track  spotify:track:3Y4rNagSf2IukhcOTWYJuV
# 6              5  track  spotify:track:0UvuqCD6ktYwIW97Pn4p2o
# 7              1  track  spotify:track:0iFhShSdYvMwscXAiUp4CT
# 8              3  track  spotify:track:15TzkwxGNvM3RGib0YkH4T
# 9             33  track  spotify:track:1ZaxUokPjgc4Po18K7t7LW
# 10             3  track  spotify:track:5EUsI3LIV042IV5ydksV9y
# 11             7  track  spotify:track:5DRUgJmwLvCHQjiFzb4LSQ
# 12             1  track  spotify:track:5xhQOnyRJfRywbEwpkgoTy
# 13             8  track  spotify:track:2Hj2yaVFXjzhQ2umr1FZCt
# 14            14  track  spotify:track:34jo30lPEqp6QvJe04NAFu
# 15             4  track  spotify:track:6NQZtrzKlUkY81Bw00avaI
# 16             6  track  spotify:track:1VRgs7pDXFcWARLa17HE9n
# 17             5  track  spotify:track:4kSIqv25W9sPsfG45rt9kh
# 18             8  track  spotify:track:653gE0Wo2LG2Hc60P2gP5s
# 19             2  track  spotify:track:5wYqKB5kuA1CTUi7NC60IQ

# %% [markdown]
# ---

# %% [markdown]
# You can always try with the [wrapper](https://github.com/plamere/spotipy)!!!
#
# ![I quit](https://media.giphy.com/media/3oFzlXPvXYZ4q8VQOs/giphy.gif)
